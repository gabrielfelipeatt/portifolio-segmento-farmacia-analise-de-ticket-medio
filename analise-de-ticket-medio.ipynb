# %% [markdown]
# 🧠 **Storytelling – Ticket Médio**
#
# O ticket médio responde a uma pergunta fundamental:
# "Quanto, em média, cada cliente está gastando por pedido?"
#
# Esse indicador é essencial para avaliar o poder de compra, a eficiência de vendas e o sucesso de estratégias de upsell e cross-sell.

# %% [markdown]
# ✅ **Pré-requisitos**
#
# Instale as bibliotecas:

# %%
pip install pandas matplotlib openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 📜 **Código Python – Análise de Ticket Médio**

# %%
# Importando bibliotecas
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1. Carregar os dados
df = pd.read_excel('/kaggle/input/dataset/dados.xlsx')

# %%
# 2. Converter coluna de data para datetime
df['data_venda'] = pd.to_datetime(df['data_venda'])

# %%
# 3. Criar coluna 'Ano-Mês'
df['Ano-Mês'] = df['data_venda'].dt.to_period('M')

# %%
# 4. Calcular Ticket Médio: Total Líquido / Quantidade
# (por mês, para acompanhar a evolução mensal)
ticket_medio_mensal = df.groupby('Ano-Mês').agg({
    'valor total liquido': 'sum',
    'quantidade': 'sum'
})
ticket_medio_mensal['Ticket Médio'] = ticket_medio_mensal['valor total liquido'] / ticket_medio_mensal['quantidade']

# %%
# 5. Plotar gráfico do Ticket Médio mensal
plt.figure(figsize=(10, 5))
ticket_medio_mensal['Ticket Médio'].plot(marker='o', color='purple')
plt.title('📊 Evolução do Ticket Médio Mensal')
plt.xlabel('Ano-Mês')
plt.ylabel('R$ por unidade')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_35/2782332348.py:8: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 6. Mostrar dados no terminal
print("📈 Tabela de Ticket Médio Mensal:\n")
print(ticket_medio_mensal[['Ticket Médio']].round(2))
# Out:
# 📈 Tabela de Ticket Médio Mensal:
#
#          Ticket Médio
# Ano-Mês
# 2020-01         26.18
# 2020-02         26.12
# 2020-03         26.00
# 2020-04         25.96
# 2020-05         26.01
# ...               ...
# 2025-01         26.47
# 2025-02         26.10
# 2025-03         26.10
# 2025-04         26.19
# 2025-05         25.78
#
# [65 rows x 1 columns]
